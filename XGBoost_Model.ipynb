# %%
# import
import numpy as np
import pandas as pd
import optuna
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import xgboost as xgb

# %%
# load file
with open('preprocessed_data/preprocessed_XGboost.pkl', 'rb') as f:
    XGBoost_preprocessed_data = pickle.load(f)

# %%
# The variable XGBoost_preprocessed_data is a list of our 5 bins [0-4][][]. Each bin contains the 15 belonging stocks or ETFs [0-4][0-14][].
# After accessing the stock we can get X_train, y_train, X_val, y_val, X_test, y_test [0-4][0-14][0-5].

# For the Tree based model the accessed data is 2D (sample_size, features)

XGBoost_preprocessed_data[0][0][4].shape
# This accesses the X_train set of the first stock in bin 1.
# Out:
# (123, 153)

# %%
# Create XGBoost objective with outer function to pass data sets
def createXGB_objective(X_train, y_train, X_val, y_val):
    def xgb_objective(trial):
        # Suggest hyperparameters
        param = {
            "verbosity": 0,
            "objective": "reg:squarederror",
            "booster": "gbtree",
            "seed": 42,
            "lambda": trial.suggest_float("lambda", 1e-3, 10.0, log=True),
            "alpha": trial.suggest_float("alpha", 1e-3, 10.0, log=True),
            "max_depth": trial.suggest_int("max_depth", 3, 10),
            "eta": trial.suggest_float("eta", 1e-4, 1e-1, log=True),
            "gamma": trial.suggest_float("gamma", 0.0, 5.0),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        }

        # prepare data for training
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dval = xgb.DMatrix(X_val, label=y_val)

        pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-rmse")

        # Train with early stopping and pruning
        trained_xgb = xgb.train(
            param,
            dtrain,
            num_boost_round=1000,
            evals=[(dval, "validation")],
            early_stopping_rounds=20,
            callbacks=[pruning_callback],
            verbose_eval=False
        )

        # predict
        y_pred = trained_xgb.predict(dval)
        
        #calculate errors
        mape   = np.mean(np.abs((y_pred - y_val) / y_val)) * 100
        rmse   = np.sqrt(mean_squared_error(y_val, y_pred))
        mae    = mean_absolute_error(y_val, y_pred)
        r2     = r2_score(y_val, y_pred)

        # store results in trial
        trial.set_user_attr("mape", mape)
        trial.set_user_attr("rmse", rmse)
        trial.set_user_attr("mae", mae)
        trial.set_user_attr("r2", r2)



        return mape
    return xgb_objective

# %%
# 5.3. XGBoost study
# number of trials
N_TRIALS = 70

# create outer list for bins
XGBoost_data_results = []
for i in range(len(XGBoost_preprocessed_data)):
    #create list per bin to store assets
    XGBoost_bin_results = []
    for j in range(len(XGBoost_preprocessed_data[i])):
        X_train, y_train, X_val, y_val, X_test, y_test = XGBoost_preprocessed_data[i][j]
        xgb_study = optuna.create_study(
            direction="minimize",
            study_name="xgb_regression_study",
            sampler=optuna.samplers.TPESampler(),
            pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
        )
        xgb_study.optimize(createXGB_objective(X_train, y_train, X_val, y_val), n_trials=N_TRIALS)

        # prepare the data sets
        params = xgb_study.best_params
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dval = xgb.DMatrix(X_val, label=y_val)
        dtest = xgb.DMatrix(X_test, label=y_test)


        # train with early stopping and pruning
        trained_xgb = xgb.train(
            params,
            dtrain,
            num_boost_round=1000,
            evals=[(dval, "validation")],
            early_stopping_rounds=20,
            verbose_eval=False
        )

        y_pred = trained_xgb.predict(dtest)

        # calculate errors
        test_mape   = np.mean(np.abs((y_pred - y_test) / y_test)) * 100
        test_rmse   = np.sqrt(mean_squared_error(y_test, y_pred))
        test_mae    = mean_absolute_error(y_test, y_pred)
        test_r2     = r2_score(y_test, y_pred)

        # store results in trial
        results = {
            "test_mape": test_mape,
            "test_rmse": test_rmse,
            "test_mae":  test_mae,
            "test_r2":   test_r2
        }


        XGBoost_bin_results.append(results)
    # write out
    with open(f'results_ret_log/XGBoost/Performance_metrices_XGBoost_bin_{i}.pkl', 'wb') as f:
        pickle.dump(XGBoost_bin_results, f)
    XGBoost_data_results.append(XGBoost_bin_results)
# write out
with open(f'results_ret_log/XGBoost/Performance_metrices_XGBoost_full.pkl', 'wb') as f:
    pickle.dump(XGBoost_data_results, f)
# Out:
# [I 2025-07-01 14:18:25,227] A new study created in memory with name: xgb_regression_study
# [I 2025-07-01 14:18:31,805] Trial 0 finished with value: 1.442744632703397 and parameters: {'lambda': 0.54591425986767, 'alpha': 5.70103591772966, 'max_depth': 8, 'eta': 0.0010966075598542464, 'gamma': 0.3445329078846915, 'subsample': 0.6530534077306617, 'colsample_bytree': 0.8724543814896596}. Best is trial 0 with value: 1.442744632703397.
# [I 2025-07-01 14:18:33,464] Trial 1 finished with value: 0.9241203775241883 and parameters: {'lambda': 2.870049656994511, 'alpha': 4.922831460012147, 'max_depth': 7, 'eta': 0.010503532482680997, 'gamma': 2.6598149779297016, 'subsample': 0.8939915570517292, 'colsample_bytree': 0.8057831634202433}. Best is trial 1 with value: 0.9241203775241883.
# [I 2025-07-01 14:18:46,045] Trial 2 finished with value: 1.9452081122082192 and parameters: {'lambda': 3.062903938503911, 'alpha': 0.0034426596368661564, 'max_depth': 4, 'eta': 0.00043807356014438414, 'gamma': 0.05416050778825898, 'subsample': 0.9774719923865747, 'colsample_bytree': 0.8893951563097249}. Best is trial 1 with value: 0.9241203775241883.
# [I 2025-07-01 14:18:50,169] Trial 3 finished with value: 0.6870596034072523 and parameters: {'lambda': 6.709264356404388, 'alpha': 0.15537179945339388, 'max_depth': 5, 'eta': 0.004891202399238186, 'gamma': 2.078375887972979, 'subsample': 0.9079983112999972, 'colsample_bytree': 0.9874266469829346}. Best is trial 3 with value: 0.6870596034072523.
# [W 2025-07-01 14:18:57,146] Trial 4 failed with parameters: {'lambda': 0.16007972159242956, 'alpha': 0.0015953144852664748, 'max_depth': 9, 'eta': 0.0010432858053443727, 'gamma': 2.810108468586066, 'subsample': 0.9066785682423064, 'colsample_bytree': 0.9817814710885548} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\jerem\AppData\Local\Temp\ipykernel_10524\1455746341.py", line 25, in xgb_objective
#     trained_xgb = xgb.train(
#                   ^^^^^^^^^^
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\training.py", line 184, in train
#     if cb_container.after_iteration(bst, i, dtrain, evals):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\callback.py", line 264, in after_iteration
#     score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py", line 2347, in eval_set
#     self._assign_dmatrix_features(d[0])
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py", line 3201, in _assign_dmatrix_features
#     ft = data.feature_types
#          ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py", line 1394, in feature_types
#     _LIB.XGDMatrixGetStrFeatureInfo(
# KeyboardInterrupt
# [W 2025-07-01 14:18:57,160] Trial 4 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 15
#       8 X_train, y_train, X_val, y_val, X_test, y_test = XGBoost_preprocessed_data[i][j]
#       9 xgb_study = optuna.create_study(
#      10     direction="minimize",
#      11     study_name="xgb_regression_study",
#      12     sampler=optuna.samplers.TPESampler(),
#      13     pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
#      14 )
# ---> 15 xgb_study.optimize(createXGB_objective(X_train, y_train, X_val, y_val), n_trials=N_TRIALS)
#      17 params = xgb_study.best_params
#      18 dtrain = xgb.DMatrix(X_train, label=y_train)
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)    382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[29], line 25, in createXGB_objective.<locals>.xgb_objective(trial)
#      22 pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-rmse")
#      24 # Train with early stopping and pruning
# ---> 25 trained_xgb = xgb.train(
#      26     param,
#      27     dtrain,
#      28     num_boost_round=1000,
#      29     evals=[(dval, "validation")],
#      30     early_stopping_rounds=20,
#      31     callbacks=[pruning_callback],
#      32     verbose_eval=False
#      33 )
#      35 y_pred = trained_xgb.predict(dval)
#      37 mape   = np.mean(np.abs((y_pred - y_val) / y_val)) * 100
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\training.py:184, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     182         break
#     183     bst.update(dtrain, iteration=i, fobj=obj)
# --> 184     if cb_container.after_iteration(bst, i, dtrain, evals):
#     185         break
#     187 bst = cb_container.after_training(bst)
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\callback.py:264, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     262 for _, name in evals:
#     263     assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 264 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     265 metric_score = _parse_eval_str(score)
#     266 self._update_history(metric_score, epoch)
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py:2347, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    2345     if not isinstance(d[1], str):
#    2346         raise TypeError(f"expected string, got {type(d[1]).__name__}")
# -> 2347     self._assign_dmatrix_features(d[0])
#    2349 dmats = c_array(ctypes.c_void_p, [d[0].handle for d in evals])
#    2350 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py:3201, in Booster._assign_dmatrix_features(self, data)
#    3198     return
#    3200 fn = data.feature_names
# -> 3201 ft = data.feature_types
#    3203 if self.feature_names is None:
#    3204     self.feature_names = fn
#
# File c:\Users\jerem\miniconda3\Lib\site-packages\xgboost\core.py:1394, in DMatrix.feature_types(self)
#    1391 length = c_bst_ulong()
#    1392 sarr = ctypes.POINTER(ctypes.c_char_p)()
#    1393 _check_call(
# -> 1394     _LIB.XGDMatrixGetStrFeatureInfo(
#    1395         self.handle,
#    1396         c_str("feature_type"),
#    1397         ctypes.byref(length),
#    1398         ctypes.byref(sarr),
#    1399     )
#    1400 )
#    1401 res = from_cstr_to_pystr(sarr, length)
#    1402 if not res:
#
# KeyboardInterrupt:
